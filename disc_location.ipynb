# %%
import SimpleITK as sitk
import numpy as np
import cv2
import os
import random
import shutil
from ultralytics import YOLO

# %%
base_dir = 'SPIDER_cleaned'
img_dir = os.path.join(base_dir, 'images')
mask_dir = os.path.join(base_dir, 'masks')

output_base = 'YOLO_SPIDER_dataset'
images_train = os.path.join(output_base, 'images/train')
images_val = os.path.join(output_base, 'images/val')
labels_train = os.path.join(output_base, 'labels/train')
labels_val = os.path.join(output_base, 'labels/val')

for d in [images_train, images_val, labels_train, labels_val]:
    if os.path.exists(d):
        shutil.rmtree(d) 
    os.makedirs(d)

LABELS_MAP = {
    201: 0, 
    202: 1, 
    203: 2, 
    204: 3, 
    205: 4  
}

def normalize_to_jpg(img_slice):
    img_min = np.min(img_slice)
    img_max = np.max(img_slice)
    if img_max == img_min:
        return np.zeros_like(img_slice, dtype=np.uint8)
    img_norm = 255.0 * (img_slice - img_min) / (img_max - img_min)
    return img_norm.astype(np.uint8)

def bounding_box(mask_slice, label_id, img_w, img_h):
    y_indices, x_indices = np.where(mask_slice == label_id)
    
    if len(x_indices) == 0 or len(y_indices) == 0:
        return None

    x_min, x_max = np.min(x_indices), np.max(x_indices)
    y_min, y_max = np.min(y_indices), np.max(y_indices)

    x_center = (x_min + x_max) / 2.0 / img_w
    y_center = (y_min + y_max) / 2.0 / img_h
    bbox_w = (x_max - x_min) / img_w
    bbox_h = (y_max - y_min) / img_h

    return (x_center, y_center, bbox_w, bbox_h)

files = sorted([f for f in os.listdir(img_dir) if f.endswith('.mha')])
random.seed(42)
random.shuffle(files)

split_idx = int(len(files) * 0.8)
train_files = files[:split_idx]
val_files = files[split_idx:]

def process_set(file_list, img_dest, lbl_dest):
    count = 0
    for filename in file_list:
        img_path = os.path.join(img_dir, filename)
        mask_path = os.path.join(mask_dir, filename)

        if not os.path.exists(mask_path):
            continue

        try:
            sitk_img = sitk.ReadImage(img_path)
            sitk_mask = sitk.ReadImage(mask_path)
            
            arr_img = sitk.GetArrayFromImage(sitk_img)
            arr_mask = sitk.GetArrayFromImage(sitk_mask)

            mid = arr_img.shape[2] // 2
            slices_to_take = [mid-1, mid, mid+1]

            for s_idx in slices_to_take:
                img_slice = arr_img[:, :, s_idx]
                mask_slice = arr_mask[:, :, s_idx]

                img_slice = np.flipud(img_slice)
                mask_slice = np.flipud(mask_slice)

                base_name = f"{filename.replace('.mha', '')}_s{s_idx}"
                jpg_name = base_name + ".jpg"
                txt_name = base_name + ".txt"

                img_uint8 = normalize_to_jpg(img_slice)
                cv2.imwrite(os.path.join(img_dest, jpg_name), img_uint8)

                labels_content = []
                h, w = mask_slice.shape
                
                for disc_id, class_id in LABELS_MAP.items():
                    bbox = bounding_box(mask_slice, disc_id, w, h)
                    if bbox:
                        labels_content.append(f"{class_id} {bbox[0]:.6f} {bbox[1]:.6f} {bbox[2]:.6f} {bbox[3]:.6f}")
                
                if labels_content:
                    with open(os.path.join(lbl_dest, txt_name), 'w') as f:
                        f.write("\n".join(labels_content))
                    count += 1

        except Exception as e:
            print(f"Error {filename}: {e}")
    return count

process_set(train_files, images_train, labels_train)
process_set(val_files, images_val, labels_val)
print("Data generation complete.")
# Out:
# Data generation complete.

# %%
model = YOLO('yolov8n.pt')

results = model.train(
    data='/Users/leniecka/python/AIiID/Projekt/spider_data.yaml',
    epochs=50,
    imgsz=320,
    batch=16,
    name='disc_location'
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 2.1MB/s 3.0s.9s<0.2s2.4s
# Ultralytics 8.3.233 🚀 Python-3.13.2 torch-2.6.0 CPU (Apple M4)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/Users/leniecka/python/AIiID/Projekt/spider_data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=320, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=disc_location, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/leniecka/python/AIiID/Projekt/runs/detect/disc_location, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752287  ultralytics.nn.modules.head.Detect           [5, [64, 128, 256]]
# Model summary: 129 layers, 3,011,823 parameters, 3,011,807 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 283.7±62.8 MB/s, size: 58.9 KB)
# train: Scanning /Users/leniecka/python/AIiID/Projekt/YOLO_SPIDER_dataset/labels/train... 504 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 504/504 4.2Kit/s 0.1s0.1s
# train: New cache created: /Users/leniecka/python/AIiID/Projekt/YOLO_SPIDER_dataset/labels/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 450.1±217.5 MB/s, size: 88.0 KB)
# val: Scanning /Users/leniecka/python/AIiID/Projekt/YOLO_SPIDER_dataset/labels/val... 126 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 126/126 4.4Kit/s 0.0s
# val: New cache created: /Users/leniecka/python/AIiID/Projekt/YOLO_SPIDER_dataset/labels/val.cache
# Plotting labels to /Users/leniecka/python/AIiID/Projekt/runs/detect/disc_location/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001111, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 320 train, 320 val
# Using 0 dataloader workers
# Logging results to /Users/leniecka/python/AIiID/Projekt/runs/detect/disc_location
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         0G      2.004      3.807       1.09         73        320: 100% ━━━━━━━━━━━━ 32/32 1.1s/it 34.3s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620     0.0187      0.869      0.205      0.106
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50         0G       1.44      1.934     0.8934         66        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.5s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.295      0.153      0.249      0.172
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50         0G      1.384      1.509     0.9045         62        320: 100% ━━━━━━━━━━━━ 32/32 1.1s/it 33.7s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.549      0.636       0.59       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50         0G      1.307      1.281     0.8884         53        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.3s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.8ss
#                    all        126        620      0.567      0.748       0.63      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50         0G      1.269      1.176     0.8819         46        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.2s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.686      0.764      0.769      0.495
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50         0G      1.246      1.148     0.8858         45        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.673      0.818      0.774      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50         0G      1.173      1.032     0.8731         69        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 32.9s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620       0.85      0.844      0.889      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50         0G      1.154      1.006     0.8667         67        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.0s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.3s1.7ss
#                    all        126        620      0.672      0.819       0.74      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50         0G      1.126     0.9744     0.8658         75        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.0s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.785      0.805      0.865      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50         0G      1.105     0.9115     0.8565         59        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.3s1.7ss
#                    all        126        620      0.858      0.905      0.926      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50         0G      1.072     0.8523     0.8545         67        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.3s1.7ss
#                    all        126        620      0.863      0.886       0.91      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50         0G      1.061     0.8413     0.8538         59        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.3s1.7ss
#                    all        126        620      0.827       0.85      0.885        0.6
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50         0G      1.085     0.8271     0.8555         69        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.5s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.916      0.878      0.921      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50         0G      1.053      0.813     0.8572         55        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.2s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.894      0.915      0.927      0.643
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50         0G      1.045     0.7639     0.8507         70        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.2s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.912      0.903      0.935      0.638
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50         0G      1.058     0.7742     0.8532         69        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.2s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.888      0.885      0.926      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50         0G      1.053     0.7515      0.852         58        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.4s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.901      0.876      0.932      0.642
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50         0G      1.027     0.7286     0.8521         85        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.4s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.903      0.901      0.935      0.645
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50         0G          1     0.6926     0.8474         50        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.3s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.809      0.876      0.853       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50         0G      1.012     0.6916     0.8414         79        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.4s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620       0.88      0.883      0.916       0.63
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50         0G      1.014      0.672     0.8413         78        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.4s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620       0.88      0.866      0.907      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50         0G      1.033     0.7096     0.8471         92        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.4s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.894      0.892       0.93      0.644
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50         0G     0.9968     0.6803     0.8369         88        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.4s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.935      0.906      0.951      0.679
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50         0G     0.9761     0.6541     0.8449         90        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.3s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.893      0.872      0.908      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50         0G     0.9763     0.6692     0.8425         62        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.4s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.934      0.911      0.947      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50         0G     0.9719     0.6481     0.8396         51        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.3s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.929      0.895      0.948       0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50         0G     0.9797     0.6236     0.8406         90        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.3s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.931      0.903      0.938      0.657
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50         0G     0.9587     0.6111      0.839         67        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.911      0.898      0.943      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50         0G     0.9516     0.6142     0.8392         61        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.5s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.908       0.91      0.933      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50         0G      0.963     0.6165     0.8351         56        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.922      0.906      0.938      0.663
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50         0G     0.9277     0.5932     0.8363         81        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.3s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.883      0.886      0.884      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50         0G     0.9289     0.6054     0.8384         66        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.3s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620       0.93      0.931      0.956      0.676
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50         0G     0.9385     0.6028     0.8381         63        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.4s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620       0.91      0.907      0.951      0.676
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50         0G     0.9291     0.5868     0.8357         41        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.4s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620       0.88      0.906      0.933      0.659
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50         0G       0.91     0.5889     0.8327         56        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.2s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.889      0.899      0.927       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50         0G     0.9101      0.556     0.8292         56        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.2s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.918      0.871      0.932      0.661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50         0G     0.9204     0.5671     0.8282         71        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.2s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.906      0.911      0.948      0.666
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50         0G     0.9208      0.562     0.8357         59        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.3s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.911      0.922      0.947       0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50         0G     0.8913     0.5511     0.8279         77        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.2s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.928      0.922      0.952      0.684
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50         0G     0.8904     0.5722     0.8334         39        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.3s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.923      0.926      0.946      0.668
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50         0G      0.818     0.4989      0.828         40        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.3s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.925      0.921       0.94      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50         0G     0.8348     0.4908     0.8275         40        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.2s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.919      0.907      0.935       0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50         0G     0.8151     0.4836     0.8303         40        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.0s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.927      0.908      0.946      0.677
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50         0G     0.8077      0.477     0.8201         40        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.2s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620       0.93      0.899      0.943      0.676
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50         0G     0.8001     0.4698     0.8223         40        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.4s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.929       0.91      0.949      0.686
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50         0G     0.7854     0.4571     0.8226         40        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.2s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.917      0.901      0.945      0.679
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50         0G     0.7847     0.4577     0.8212         40        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.2s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.924      0.899      0.941      0.687
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50         0G     0.7877     0.4513     0.8277         39        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.1s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620       0.93        0.9      0.939       0.68
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50         0G     0.7649      0.448     0.8248         40        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.2s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.931        0.9      0.942      0.684
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50         0G     0.7744     0.4452     0.8216         40        320: 100% ━━━━━━━━━━━━ 32/32 1.0s/it 33.2s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.934       0.89       0.94      0.681
#
# 50 epochs completed in 0.524 hours.
# Optimizer stripped from /Users/leniecka/python/AIiID/Projekt/runs/detect/disc_location/weights/last.pt, 6.2MB
# Optimizer stripped from /Users/leniecka/python/AIiID/Projekt/runs/detect/disc_location/weights/best.pt, 6.2MB
#
# Validating /Users/leniecka/python/AIiID/Projekt/runs/detect/disc_location/weights/best.pt...
# Ultralytics 8.3.233 🚀 Python-3.13.2 torch-2.6.0 CPU (Apple M4)
# Model summary (fused): 72 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.4s1.7ss
#                    all        126        620      0.925      0.899      0.941      0.687
#                  L5/S1        126        126       0.87       0.85      0.874      0.717
#                  L4/L5        126        126      0.891      0.907      0.904      0.653
#                  L3/L4        126        126      0.969      0.897      0.979      0.705
#                  L2/L3        122        122       0.95      0.932      0.983       0.68
#                  L1/L2        120        120      0.943      0.908      0.964      0.681
# Speed: 0.1ms preprocess, 31.8ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /Users/leniecka/python/AIiID/Projekt/runs/detect/disc_location
